# %%
import pandas_datareader as data
import pandas as pd
import datetime
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
start = datetime.datetime(2020, 12, 31)
end = datetime.datetime(2021, 12, 31)

# %%
df = data.DataReader("NVDA", 'yahoo', start, end)
df.head(5)
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2020-12-30  132.137497  128.967499  129.902496  131.457504  22539600.0
# 2020-12-31  131.509995  129.149994  131.365005  130.550003  19242400.0
# 2021-01-04  136.524994  129.625000  131.042496  131.134995  56064000.0
# 2021-01-05  134.434998  130.869995  130.997498  134.047501  32276000.0
# 2021-01-06  132.449997  125.860001  132.225006  126.144997  58042400.0
#
#              Adj Close
# Date
# 2020-12-30  131.342789
# 2020-12-31  130.436081
# 2021-01-04  131.020569
# 2021-01-05  133.930527
# 2021-01-06  126.034912

# %%
plt.figure(figsize = (14,7))
plt.plot(df.Close)

# %%
import numpy as np
df.plot.bar(y="Volume",xlabel='date',ylabel='vol', color="Blue")
# Out:
# <AxesSubplot:xlabel='date', ylabel='vol'>
